# %% [markdown]
# # Xpath
# - XPath란 XML Path Language를 의미
# - XPath는 XML 문서의 특정 요소나 속성에 접근하기 위한 경로를 지정하는 언어
#
# ```
# XPath의 특징
# XPath는 XML 문서의 일부분을 선택하고 처리하기 위해 만들어진 언어입니다.
#
# 이러한 XPath는 다음과 같은 특징을 가집니다.
#
#
#
# 1. XPath는 XML 문서를 탐색하기 위해 경로 표현식(path expression)을 사용합니다.
#
# 2. XPath는 수학, 문자열 처리 등을 하기 위한 표준 함수 라이브러리를 내장하고 있습니다.
#
# 3. XPath는 W3C의 표준 권고안인 XSLT에서 가장 중요한 부분 중 하나입니다.
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 각 태그함수를 잘 기억하고
# - 개발자 모드의 코드에서 확인

# %% [markdown]
# # 국민 청원 데이터

# %%
import requests
from lxml import html
url = "https://www1.president.go.kr/petitions/best"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36 Edg/95.0.1020.53'}
html_req = requests.get(url, headers=headers)
tree = html.fromstring(html_req.text)
# titles = tree.xpath('//a[@class="cb"]/text()')
titles = tree.xpath('//div[@class="bl_subject"]/a[@class="cb"]/text()')

results = []
for title in titles:
    title_clean = title.replace("\n", " ").replace("\t", " ").replace("\r", " ").strip()
    results.append(title_clean)
    print(title)  #  제목
print(len(results)) # 길이
print(results)
# Out:
# 윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조…
# 윤석열 당선인 집무실 만들고자, 국가안전 중추인 국방부를 강압 이전하여, 국민의 혈세 수천…
# 이명박 전 대통령 사면을 반대합니다.
# 문재인 대통령님 사랑합니다.
# 대구 동구 부정선거 및 선거관리위원회의 관리 부실로 대선 재투표를 희망합니다.
# 제 20대 대통령의 집무실 이전에 반대합니다.
# 당선인의 대통령집무실과 공관이전을 찬성합니다. 공약이행을 반드시 해주시길 청원드립니다.
# 성범죄 피해자입니다. 여가부 폐지 반대합니다.
# 의료 민영화의 첫 걸음이 될 제주 영리병원을 국가가 매수해주십시오.
# 국가보안법 목적수행죄 위반 윤석열 당선자를 처벌해주세요
# 폐양식장에서 취미로 고양이 해부를 즐기던 *** 학대범을 ***을 강력히 처벌해주세요.
# 윤석열 총장 당시 검찰 특활비 147억  공개 청원합니다.
# 무궁화대훈장 셀프수여 반대
# 제발 지하철 9호선 폭행녀를 꼭 강력 처벌을 하여 일벌백계하여 주세요.
# 퇴임하기전에 검찰 수사권 기소권 분리를 끝내주세요.
# 15
# ['윤석열 당선자의 대장동 부산저축은행 부실수사 봐주기 의혹과 김건희의 주가조작 실체의 진상조…', '윤석열 당선인 집무실 만들고자, 국가안전 중추인 국방부를 강압 이전하여, 국민의 혈세 수천…', '이명박 전 대통령 사면을 반대합니다.', '문재인 대통령님 사랑합니다.', '대구 동구 부정선거 및 선거관리위원회의 관리 부실로 대선 재투표를 희망합니다.', '제 20대 대통령의 집무실 이전에 반대합니다.', '당선인의 대통령집무실과 공관이전을 찬성합니다. 공약이행을 반드시 해주시길 청원드립니다.', '성범죄 피해자입니다. 여가부 폐지 반대합니다.', '의료 민영화의 첫 걸음이 될 제주 영리병원을 국가가 매수해주십시오.', '국가보안법 목적수행죄 위반 윤석열 당선자를 처벌해주세요', '폐양식장에서 취미로 고양이 해부를 즐기던 *** 학대범을 ***을 강력히 처벌해주세요.', '윤석열 총장 당시 검찰 특활비 147억  공개 청원합니다.', '무궁화대훈장 셀프수여 반대', '제발 지하철 9호선 폭행녀를 꼭 강력 처벌을 하여 일벌백계하여 주세요.', '퇴임하기전에 검찰 수사권 기소권 분리를 끝내주세요.']

# %% [markdown]
# # Steam 게임 순위 데이터

# %%
import requests
from lxml import html
url = "https://store.steampowered.com/search/?filter=topsellers"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36 Edg/95.0.1020.53'}
html_req = requests.get(url, headers=headers)
tree = html.fromstring(html_req.text)
titles = tree.xpath('//span[@class="title"]/text()')
# titles = tree.xpath('//[@class="bl_subject"]/a[@class="cb"]/text()')

results = []
for title in titles:
    title_clean = title.replace("\n", " ").replace("\t", " ").replace("\r", " ").strip()
    results.append(title_clean)
    print(title)
print(len(results))
print(results)
# Out:
# ELDEN RING
# Longvinter
# Weird West
# Grand Theft Auto V: Premium Edition
# Red Dead Redemption 2
# Ghostwire: Tokyo
# DEATH STRANDING DIRECTOR'S CUT
# Have a Nice Death
# Raft
# BURIED STARS
# The Planet Crafter
# Escape Simulator
# Core Keeper
# Football Manager 2022
# God of War
# Project Zomboid
# Destiny 2: The Witch Queen Deluxe + Bungie 30th Anniversary Bundle
# Spiritfarer®: Farewell Edition
# Stardew Valley
# Coromon
# Destiny 2: The Witch Queen
# Gang Beasts
# WWE 2K22
# Coffee Talk
# MONSTER HUNTER RISE
# Dying Light 2 Stay Human
# Mount & Blade II: Bannerlord
# World War 3
# Green Hell
# Sid Meier’s Civilization® VI Anthology
# Ready or Not
# A Dance of Fire and Ice
# Grand Theft Auto V - Criminal Enterprise Starter Pack
# ARK: Survival Evolved
# Death's Door
# ARK: Ultimate Survivor Edition
# House Flipper
# The Forest
# Human: Fall Flat
# Borderlands 3
# TEKKEN 7
# Vampire Survivors
# ROMANCE OF THE THREE KINGDOMS XIV: Diplomacy and Strategy Expansion Pack Bundle
# Valheim
# Monster Hunter Rise: Sunbreak
# Destiny 2: The Witch Queen Deluxe Edition
# GROUND BRANCH
# The Binding of Isaac: Rebirth Complete Bundle
# Farming Simulator 22
# Dealer's Life 2
# 50
# ['ELDEN RING', 'Longvinter', 'Weird West', 'Grand Theft Auto V: Premium Edition', 'Red Dead Redemption 2', 'Ghostwire: Tokyo', "DEATH STRANDING DIRECTOR'S CUT", 'Have a Nice Death', 'Raft', 'BURIED STARS', 'The Planet Crafter', 'Escape Simulator', 'Core Keeper', 'Football Manager 2022', 'God of War', 'Project Zomboid', 'Destiny 2: The Witch Queen Deluxe + Bungie 30th Anniversary Bundle', 'Spiritfarer®: Farewell Edition', 'Stardew Valley', 'Coromon', 'Destiny 2: The Witch Queen', 'Gang Beasts', 'WWE 2K22', 'Coffee Talk', 'MONSTER HUNTER RISE', 'Dying Light 2 Stay Human', 'Mount & Blade II: Bannerlord', 'World War 3', 'Green Hell', 'Sid Meier’s Civilization® VI Anthology', 'Ready or Not', 'A Dance of Fire and Ice', 'Grand Theft Auto V - Criminal Enterprise Starter Pack', 'ARK: Survival Evolved', "Death's Door", 'ARK: Ultimate Survivor Edition', 'House Flipper', 'The Forest', 'Human: Fall Flat', 'Borderlands 3', 'TEKKEN 7', 'Vampire Survivors', 'ROMANCE OF THE THREE KINGDOMS XIV: Diplomacy and Strategy Expansion Pack Bundle', 'Valheim', 'Monster Hunter Rise: Sunbreak', 'Destiny 2: The Witch Queen Deluxe Edition', 'GROUND BRANCH', 'The Binding of Isaac: Rebirth Complete Bundle', 'Farming Simulator 22', "Dealer's Life 2"]

# %% [markdown]
# # Steam 게임 상세데이터

# %%
import requests
from lxml import html
# url = "https://store.steampowered.com/search/?filter=topsellers"
url ='https://store.steampowered.com/explore/new/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36 Edg/95.0.1020.53'}
html_req = requests.get(url, headers=headers)
tree = html.fromstring(html_req.text)
# titles = tree.xpath('//span[@class="title"]/text()')

#신규출시 - 신규출시 인기제품의 게임유형태그 toptag
titles = tree.xpath('//div[@class="tab_item_top_tags"]/span[@class="top_tag"]/text()')  


# titles = tree.xpath('//a[@class="cb"]/text()')
# titles = tree.xpath('//div[@class="bl_subject"]/a[@class="cb"]/text()')

results = []
for title in titles:
    title_clean = title.replace("\n", " ").replace("\t", " ").replace("\r", " ").strip()
    results.append(title_clean)
    print(title)  # 제목
print(len(results))# 길이
print(results)
# Out:
# Indie
# , Racing
# , Horses
# , Online Co-Op
# Creature Collector
# , Collectathon
# , Turn-Based
# , Difficult
# RPG
# , Adventure
# , JRPG
# , Voxel
# Western
# , Isometric
# , RPG
# , Immersive Sim
# Action
# , Adventure
# , Walking Simulator
# , Exploration
# Sokoban
# , Puzzle
# , Abstract
# , Minimalist
# Roguelike
# , Strategy
# , Card Game
# , Dungeon Crawler
# RPG
# , Party-Based RPG
# , Dungeons & Dragons
# , Fantasy
# RPG
# , Turn-Based Combat
# , Fantasy
# , Dungeons & Dragons
# FPS
# , Looter Shooter
# , Retro
# , Violent
# Free to Play
# , Indie
# , Short
# , Dark Comedy
# Indie
# , Strategy
# , RPG
# , Mod
# Action
# , Casual
# , Multiplayer
# , Arcade
# Singleplayer
# , Supernatural
# , First-Person
# , Action-Adventure
# Singleplayer
# , Supernatural
# , First-Person
# , Action-Adventure
# Life Sim
# , Dog
# , Cats
# , Education
# Utilities
# , Video Production
# , Free to Play
# , Souls-like
# Casual
# , Idler
# , Clicker
# , Ninja
# Action
# , 2D Fighter
# , Anime
# , Fighting
# Sports
# , Snowboarding
# , Multiplayer
# , Character Customization
# Exploration
# , Puzzle
# , RPG
# , Souls-like
# Dog
# , Sandbox
# , Cute
# , Life Sim
# Simulation
# , Sports
# , PvP
# , Local Co-Op
# City Builder
# , Building
# , Management
# , Sandbox
# Action
# , Multiplayer
# , Casual
# , Funny
# Adventure
# , Action RPG
# , Action-Adventure
# , Sandbox
# Dark Humor
# , Horror
# , Tactical
# , Turn-Based Strategy
# Co-op Campaign
# , Hand-drawn
# , Cute
# , Casual
# Co-op Campaign
# , Hand-drawn
# , Cute
# , Casual
# Action
# , Casual
# , Massively Multiplayer
# , Indie
# Free to Play
# , Singleplayer
# , Action
# , Casual
# Local Co-Op
# , Strategy
# , Auto Battler
# , Turn-Based Strategy
# Sandbox
# , America
# , Shooter
# , Multiplayer
# Action
# , Indie
# , Co-op
# , Action Roguelike
# Action
# , Shooter
# , FPS
# , Multiplayer
# Souls-like
# , Relaxing
# , Dark Fantasy
# , RPG
# Casual
# , Adventure
# , Simulation
# , RPG
# Choose Your Own Adventure
# , Exploration
# , RPG
# , Interactive Fiction
# Nature
# , Realistic
# , Simulation
# , Education
# Simulation
# , Strategy
# , Building
# , God Game
# Survival Horror
# , Puzzle
# , Pixel Graphics
# , Exploration
# Action
# , Action Roguelike
# , Roguelike
# , Shooter
# Arena Shooter
# , PvP
# , PvE
# , Arcade
# Action
# , Shooter
# , FPS
# , 3D
# Action
# , Adventure
# , Action-Adventure
# , Top-Down Shooter
# Casual
# , Strategy
# , Turn-Based Strategy
# , Board Game
# Exploration
# , 3D Platformer
# , Puzzle Platformer
# , Platformer
# Casual
# , Runner
# , Linear
# , Funny
# Adventure
# , Casual
# , Strategy
# , Turn-Based Strategy
# Metroidvania
# , 2D Platformer
# , Platformer
# , Action-Adventure
# Strategy
# , Stealth
# , Open World
# , Shooter
# Casual
# , RPG
# , JRPG
# , Roguelite
# Casual
# , Strategy
# , Tower Defense
# , Wargame
# Casual
# , Arcade
# , Puzzle
# , Puzzle Platformer
# Open World
# , Physics
# , Destruction
# , Funny
# Multiplayer
# , Tactical
# , Sandbox
# , Simulation
# Action
# , Adventure
# , RPG
# , Action-Adventure
# Adventure
# , Drama
# , Story Rich
# , Interactive Fiction
# Strategy
# , Indie
# , Singleplayer
# , First-Person
# Precision Platformer
# , Difficult
# , Platformer
# , 2D
# Adventure
# , Casual
# , Simulation
# , Visual Novel
# Strategy
# , Simulation
# , Casual
# , City Builder
# Casual
# , Adventure
# , Action
# , RPG
# Vehicular Combat
# , Base Building
# , Post-apocalyptic
# , Survival
# Open World
# , Adventure
# , Family Friendly
# , RPG
# 2D Platformer
# , Runner
# , PvE
# , PvP
# Casual
# , 3D Platformer
# , Platformer
# , 3D
# Souls-like
# , Action RPG
# , Action-Adventure
# , Character Customization
# Exploration
# , Mystery
# , Collectathon
# , Top-Down
# Exploration
# , Mystery
# , Collectathon
# , Top-Down
# 280
# ['Indie', ', Racing', ', Horses', ', Online Co-Op', 'Creature Collector', ', Collectathon', ', Turn-Based', ', Difficult', 'RPG', ', Adventure', ', JRPG', ', Voxel', 'Western', ', Isometric', ', RPG', ', Immersive Sim', 'Action', ', Adventure', ', Walking Simulator', ', Exploration', 'Sokoban', ', Puzzle', ', Abstract', ', Minimalist', 'Roguelike', ', Strategy', ', Card Game', ', Dungeon Crawler', 'RPG', ', Party-Based RPG', ', Dungeons & Dragons', ', Fantasy', 'RPG', ', Turn-Based Combat', ', Fantasy', ', Dungeons & Dragons', 'FPS', ', Looter Shooter', ', Retro', ', Violent', 'Free to Play', ', Indie', ', Short', ', Dark Comedy', 'Indie', ', Strategy', ', RPG', ', Mod', 'Action', ', Casual', ', Multiplayer', ', Arcade', 'Singleplayer', ', Supernatural', ', First-Person', ', Action-Adventure', 'Singleplayer', ', Supernatural', ', First-Person', ', Action-Adventure', 'Life Sim', ', Dog', ', Cats', ', Education', 'Utilities', ', Video Production', ', Free to Play', ', Souls-like', 'Casual', ', Idler', ', Clicker', ', Ninja', 'Action', ', 2D Fighter', ', Anime', ', Fighting', 'Sports', ', Snowboarding', ', Multiplayer', ', Character Customization', 'Exploration', ', Puzzle', ', RPG', ', Souls-like', 'Dog', ', Sandbox', ', Cute', ', Life Sim', 'Simulation', ', Sports', ', PvP', ', Local Co-Op', 'City Builder', ', Building', ', Management', ', Sandbox', 'Action', ', Multiplayer', ', Casual', ', Funny', 'Adventure', ', Action RPG', ', Action-Adventure', ', Sandbox', 'Dark Humor', ', Horror', ', Tactical', ', Turn-Based Strategy', 'Co-op Campaign', ', Hand-drawn', ', Cute', ', Casual', 'Co-op Campaign', ', Hand-drawn', ', Cute', ', Casual', 'Action', ', Casual', ', Massively Multiplayer', ', Indie', 'Free to Play', ', Singleplayer', ', Action', ', Casual', 'Local Co-Op', ', Strategy', ', Auto Battler', ', Turn-Based Strategy', 'Sandbox', ', America', ', Shooter', ', Multiplayer', 'Action', ', Indie', ', Co-op', ', Action Roguelike', 'Action', ', Shooter', ', FPS', ', Multiplayer', 'Souls-like', ', Relaxing', ', Dark Fantasy', ', RPG', 'Casual', ', Adventure', ', Simulation', ', RPG', 'Choose Your Own Adventure', ', Exploration', ', RPG', ', Interactive Fiction', 'Nature', ', Realistic', ', Simulation', ', Education', 'Simulation', ', Strategy', ', Building', ', God Game', 'Survival Horror', ', Puzzle', ', Pixel Graphics', ', Exploration', 'Action', ', Action Roguelike', ', Roguelike', ', Shooter', 'Arena Shooter', ', PvP', ', PvE', ', Arcade', 'Action', ', Shooter', ', FPS', ', 3D', 'Action', ', Adventure', ', Action-Adventure', ', Top-Down Shooter', 'Casual', ', Strategy', ', Turn-Based Strategy', ', Board Game', 'Exploration', ', 3D Platformer', ', Puzzle Platformer', ', Platformer', 'Casual', ', Runner', ', Linear', ', Funny', 'Adventure', ', Casual', ', Strategy', ', Turn-Based Strategy', 'Metroidvania', ', 2D Platformer', ', Platformer', ', Action-Adventure', 'Strategy', ', Stealth', ', Open World', ', Shooter', 'Casual', ', RPG', ', JRPG', ', Roguelite', 'Casual', ', Strategy', ', Tower Defense', ', Wargame', 'Casual', ', Arcade', ', Puzzle', ', Puzzle Platformer', 'Open World', ', Physics', ', Destruction', ', Funny', 'Multiplayer', ', Tactical', ', Sandbox', ', Simulation', 'Action', ', Adventure', ', RPG', ', Action-Adventure', 'Adventure', ', Drama', ', Story Rich', ', Interactive Fiction', 'Strategy', ', Indie', ', Singleplayer', ', First-Person', 'Precision Platformer', ', Difficult', ', Platformer', ', 2D', 'Adventure', ', Casual', ', Simulation', ', Visual Novel', 'Strategy', ', Simulation', ', Casual', ', City Builder', 'Casual', ', Adventure', ', Action', ', RPG', 'Vehicular Combat', ', Base Building', ', Post-apocalyptic', ', Survival', 'Open World', ', Adventure', ', Family Friendly', ', RPG', '2D Platformer', ', Runner', ', PvE', ', PvP', 'Casual', ', 3D Platformer', ', Platformer', ', 3D', 'Souls-like', ', Action RPG', ', Action-Adventure', ', Character Customization', 'Exploration', ', Mystery', ', Collectathon', ...

# %% [markdown]
# # 네이버 뉴스

# %%
import requests
from lxml import html
# 네이버 뉴스 
url = "https://search.naver.com/search.naver?where=news&query=%ED%82%A5%EB%B3%B4%EB%93%9C&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2021.01.01&de=2021.04.30&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210101to20210430&is_sug_officeid=0"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36 Edg/95.0.1020.53'}
html_req = requests.get(url, headers=headers)
tree = html.fromstring(html_req.text)

# .//    -> 선택한 부분에서만
bodies = tree.xpath('//ul[@class="list_news"]/li')

results = []
for body in bodies:
    news_title = body.xpath('.//a[@class="news_tit"]/@title')[0]
    try:
        news_url = body.xpath('.//a[@class="info"/@href')[0]
    except:
        news_url =''
    news_title_clean = news_title.replace("\n", " ").replace("\t", " ").replace("\r", " ").strip()
    results.append(news_title_clean)
    print(news_title_clean)
print(len(results))
print(results)
# Out:
# [B tv 한빛뉴스][데스크 노트] 위험천만 공유 킥보드 해법은 없나?
# 팅크웨어, 전동 킥보드 아이나비 스포츠 로드 기어 GT 출시
# 빔모빌리티와 부산교통공사, 부산지역 모빌리티 활성화 위한 업무협약 체결
# 백원킥보드 쓩, 2021년 형 MAX 킥보드 공급 통한 안정성 모색
# "킥보드, 안전 또 안전"...업계·지자체·경찰, 환경개선 총력
# 세븐일레븐, 가정의달 맞이 ‘가족사랑 선물세트’ 출시
# ‘빨대퀸’ 홍현희, 역대급 힘든 N잡에 멘붕..촬영 중 강제 다이어트?
# 공유 킥보드 디어 ‘1분 90원’ 배민커넥터 발 된다
# '빨대퀸' 홍현희, 촬영하다 강제 다이어트... 역대급 N잡
# 디어, 배민커넥트와 달린다
# 10
# ['[B tv 한빛뉴스][데스크 노트] 위험천만 공유 킥보드 해법은 없나?', '팅크웨어, 전동 킥보드 아이나비 스포츠 로드 기어 GT 출시', '빔모빌리티와 부산교통공사, 부산지역 모빌리티 활성화 위한 업무협약 체결', '백원킥보드 쓩, 2021년 형 MAX 킥보드 공급 통한 안정성 모색', '"킥보드, 안전 또 안전"...업계·지자체·경찰, 환경개선 총력', '세븐일레븐, 가정의달 맞이 ‘가족사랑 선물세트’ 출시', '‘빨대퀸’ 홍현희, 역대급 힘든 N잡에 멘붕..촬영 중 강제 다이어트?', '공유 킥보드 디어 ‘1분 90원’ 배민커넥터 발 된다', "'빨대퀸' 홍현희, 촬영하다 강제 다이어트... 역대급 N잡", '디어, 배민커넥트와 달린다']
